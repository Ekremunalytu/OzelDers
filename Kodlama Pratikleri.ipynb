# %% [markdown]
# Hackerrank Çalışması
#  Print Ödevi: https://www.hackerrank.com/domains/python?filters%5Bsubdomains%5D%5B%5D=py-introduction
# İf Else Ödevi: https://www.hackerrank.com/challenges/py-if-else/problem?isFullScreen=true
# Aritmetik İş Ödevi: https://www.hackerrank.com/challenges/python-arithmetic-operators/problem?isFullScreen=true
# Mod ve Bölme İşlemi: https://www.hackerrank.com/challenges/python-division/problem?isFullScreen=true
# Genel Simülasyon: https://chatgpt.com/canvas/shared/69ac79e5ab10819182cfc54746feb6ce
